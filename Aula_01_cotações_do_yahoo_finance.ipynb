# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Bento/proj_investimentos-py/blob/main/Aula_01_cota%C3%A7%C3%B5es_do_yahoo_finance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando dados do Yahoo finances e exibindo os dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# Instale e atualize yfinance se ainda não foi feito
# !pip install yfinance --upgrade --no-cache-dir

# Importe yfinance
import yfinance as yf

# Obtenha dados diretamente usando yfinance
ticker = "AAPL"
start_date = "2020-01-01"
end_date = "2021-01-01"

try:
    # Obtenha dados diretamente com yfinance
    data = yf.download(ticker, start=start_date, end=end_date)
    print(data.head())
except Exception as e:
    print(f"Erro ao obter dados: {e}")
# Out:
# ...
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960464  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251144  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826843  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484344  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200

# %% [markdown]
# # Obtendo os dados do mercado

# %%
ibov = yf.download('^BVSP')
print(ibov.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
print(ibov.tail())
# Out:
#                      Open           High           Low      Close  Adj Close  \
# Date
# 2024-07-30  126951.000000  126951.000000  125973.00000  126139.00  126139.00
# 2024-07-31  126139.000000  127853.000000  126139.00000  127652.00  127652.00
# 2024-08-01  127652.000000  128762.000000  127150.00000  127395.00  127395.00
# 2024-08-02  127395.000000  128104.000000  125731.00000  125854.00  125854.00
# 2024-08-05  125850.507812  125850.507812  123073.15625  125061.25  125061.25
#
#              Volume
# Date
# 2024-07-30  6848600
# 2024-07-31  9471900
# 2024-08-01  9814200
# 2024-08-02  9950900
# 2024-08-05        0

# %%
ibov["Close"].plot(figsize=(22,8))
# Out:
# <Axes: xlabel='Date'>
